# %%
import scanpy as sc
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
adata = sc.read_h5ad("/u/project/cluo/ekliao/alzheimers/Code2/processed_Micro-PVM_AD.h5ad")

# %%
sc.pl.umap(adata, color='leiden', legend_loc='on data')
